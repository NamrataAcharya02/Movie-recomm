# %%
import numpy as np
import pandas as pd

# %%
movies = pd.read_csv('tmdb_5000_movies.csv')
credits = pd.read_csv('tmdb_5000_credits.csv')

# %%
movies.head(1)
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                       homepage     id  \
# 0  http://www.avatarmovie.com/  19995
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
#
#   original_title                                           overview  \
# 0         Avatar  In the 22nd century, a paraplegic Marine is di...
#
#    popularity                               production_companies  \
# 0  150.437577  [{"name": "Ingenious Film Partners", "id": 289...
#
#                                 production_countries release_date     revenue  \
# 0  [{"iso_3166_1": "US", "name": "United States o...   2009-12-10  2787965087
#
#    runtime                                   spoken_languages    status  \
# 0    162.0  [{"iso_639_1": "en", "name": "English"}, {"iso...  Released
#
#                        tagline   title  vote_average  vote_count
# 0  Enter the World of Pandora.  Avatar           7.2       11800

# %%
credits.head(1)
# Out:
#    movie_id   title                                               cast  \
# 0     19995  Avatar  [{"cast_id": 242, "character": "Jake Sully", "...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...

# %%
dataset = movies.merge(credits, on='title')

# %%
dataset.shape
dataset.head()
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# 2  [{"id": 470, "name": "spy"}, {"id": 818, "name...                en
# 3  [{"id": 849, "name": "dc comics"}, {"id": 853,...                en
# 4  [{"id": 818, "name": "based on novel"}, {"id":...                en
#
#                              original_title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
# 2                                   Spectre
# 3                     The Dark Knight Rises
# 4                               John Carter
#
#                                             overview  popularity  \
# 0  In the 22nd century, a paraplegic Marine is di...  150.437577
# 1  Captain Barbossa, long believed to be dead, ha...  139.082615
# 2  A cryptic message from Bond’s past sends him o...  107.376788
# 3  Following the death of District Attorney Harve...  112.312950
# 4  John Carter is a war-weary, former military ca...   43.926995
#
#                                 production_companies  ... runtime  \
# 0  [{"name": "Ingenious Film Partners", "id": 289...  ...   162.0
# 1  [{"name": "Walt Disney Pictures", "id": 2}, {"...  ...   169.0
# 2  [{"name": "Columbia Pictures", "id": 5}, {"nam...  ...   148.0
# 3  [{"name": "Legendary Pictures", "id": 923}, {"...  ...   165.0
# 4        [{"name": "Walt Disney Pictures", "id": 2}]  ...   132.0
#
#                                     spoken_languages    status  \
# 0  [{"iso_639_1": "en", "name": "English"}, {"iso...  Released
# 1           [{"iso_639_1": "en", "name": "English"}]  Released
# 2  [{"iso_639_1": "fr", "name": "Fran\u00e7ais"},...  Released
# 3           [{"iso_639_1": "en", "name": "English"}]  Released
# 4           [{"iso_639_1": "en", "name": "English"}]  Released
#
#                                           tagline  \
# 0                     Enter the World of Pandora.
# 1  At the end of the world, the adventure begins.
# 2                           A Plan No One Escapes
# 3                                 The Legend Ends
# 4            Lost in our world, found in another.
#
#                                       title vote_average vote_count movie_id  \
# 0                                    Avatar          7.2      11800    19995
# 1  Pirates of the Caribbean: At World's End          6.9       4500      285
# 2                                   Spectre          6.3       4466   206647
# 3                     The Dark Knight Rises          7.6       9106    49026
# 4                               John Carter          6.1       2124    49529
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
# 1  [{"cast_id": 4, "character": "Captain Jack Spa...
# 2  [{"cast_id": 1, "character": "James Bond", "cr...
# 3  [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# 4  [{"cast_id": 5, "character": "John Carter", "c...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...
# 1  [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 2  [{"credit_id": "54805967c3a36829b5002c41", "de...
# 3  [{"credit_id": "52fe4781c3a36847f81398c3", "de...
# 4  [{"credit_id": "52fe479ac3a36847f813eaa3", "de...
#
# [5 rows x 23 columns]

# %%
#columns to keep: id, genres, keywords. Not keeping
#original language bec most are eng so creates imbalance. Keep title, 
#overview, cast, crew

movies = dataset[['movie_id', 'title', 'overview', 'genres', 'keywords', 'cast', 'crew']]

# %%
movies.head(1)
# Out:
#    movie_id   title                                           overview  \
# 0     19995  Avatar  In the 22nd century, a paraplegic Marine is di...
#
#                                               genres  \
# 0  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                             keywords  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...

# %%
#Aim: Use this movies df to make a new df with movie_id, title, tags. Tags is a merge of overview, genres, keywords, cast, crew

# %%
movies.isnull().sum()
# Out:
# movie_id    0
# title       0
# overview    0
# genres      0
# keywords    0
# cast        0
# crew        0
# dtype: int64

# %%
movies.dropna(inplace=True)
# Out:
# <ipython-input-14-4d2d825739df>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movies.dropna(inplace=True)

# %%
movies.duplicated().sum()
# Out:
# 0

# %%
movies.iloc[0]['genres']
# Out:
# '[{"id": 28, "name": "Action"}, {"id": 12, "name": "Adventure"}, {"id": 14, "name": "Fantasy"}, {"id": 878, "name": "Science Fiction"}]'

# %%
import json

# %%
#edit format of genres column to only list of the 'name' values

def convert(obj, key):
    list = json.loads(obj)
    newlist = [d[key] for d in list]
    return newlist

# %%
def convertcast(obj, key):
    list = json.loads(obj)
    newlist = [d[key] for d in list]
    return newlist[:3]

# %%
convert(movies.iloc[0]['genres'], 'name')
# Out:
# ['Action', 'Adventure', 'Fantasy', 'Science Fiction']

# %%
movies['genres'] = movies['genres'].apply(convert, key='name')
# Out:
# <ipython-input-31-0ac846debeb7>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movies['genres'] = movies['genres'].apply(convert, key='name')

# %%
movies['genres'].head()
# Out:
# 0    [Action, Adventure, Fantasy, Science Fiction]
# 1                     [Adventure, Fantasy, Action]
# 2                       [Action, Adventure, Crime]
# 3                 [Action, Crime, Drama, Thriller]
# 4             [Action, Adventure, Science Fiction]
# Name: genres, dtype: object

# %%
movies['keywords'] = movies['keywords'].apply(convert, key='name')
# Out:
# <ipython-input-33-e7b457a010c2>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movies['keywords'] = movies['keywords'].apply(convert, key='name')

# %%
movies['keywords'].head()
# Out:
# 0    [culture clash, future, space war, space colon...
# 1    [ocean, drug abuse, exotic island, east india ...
# 2    [spy, based on novel, secret agent, sequel, mi...
# 3    [dc comics, crime fighter, terrorist, secret i...
# 4    [based on novel, mars, medallion, space travel...
# Name: keywords, dtype: object

# %%
movies['cast'] = movies['cast'].apply(convertcast, key='name')
# Out:
# <ipython-input-40-ee2a98e1c674>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movies['cast'] = movies['cast'].apply(convertcast, key='name')

# %%
movies['cast'].head()
# Out:
# 0    [Sam Worthington, Zoe Saldana, Sigourney Weaver]
# 1       [Johnny Depp, Orlando Bloom, Keira Knightley]
# 2        [Daniel Craig, Christoph Waltz, Léa Seydoux]
# 3        [Christian Bale, Michael Caine, Gary Oldman]
# 4      [Taylor Kitsch, Lynn Collins, Samantha Morton]
# Name: cast, dtype: object

# %%
#convert crew to director

def fetch_director(obj):
    list = json.loads(obj)
    for d in list:
        if d['job'] == 'Director':
            return [d['name']]

# %%
movies['crew'] = movies['crew'].apply(fetch_director)
# Out:
# <ipython-input-44-1e2791f73e30>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movies['crew'] = movies['crew'].apply(fetch_director)

# %%
movies.rename(columns={'crew':'director'}, inplace=True)
movies.head()
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:4441: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                             overview  \
# 0  In the 22nd century, a paraplegic Marine is di...
# 1  Captain Barbossa, long believed to be dead, ha...
# 2  A cryptic message from Bond’s past sends him o...
# 3  Following the death of District Attorney Harve...
# 4  John Carter is a war-weary, former military ca...
#
#                                           genres  \
# 0  [Action, Adventure, Fantasy, Science Fiction]
# 1                   [Adventure, Fantasy, Action]
# 2                     [Action, Adventure, Crime]
# 3               [Action, Crime, Drama, Thriller]
# 4           [Action, Adventure, Science Fiction]
#
#                                             keywords  \
# 0  [culture clash, future, space war, space colon...
# 1  [ocean, drug abuse, exotic island, east india ...
# 2  [spy, based on novel, secret agent, sequel, mi...
# 3  [dc comics, crime fighter, terrorist, secret i...
# 4  [based on novel, mars, medallion, space travel...
#
#                                                cast           director
# 0  [Sam Worthington, Zoe Saldana, Sigourney Weaver]      James Cameron
# 1     [Johnny Depp, Orlando Bloom, Keira Knightley]     Gore Verbinski
# 2      [Daniel Craig, Christoph Waltz, Léa Seydoux]         Sam Mendes
# 3      [Christian Bale, Michael Caine, Gary Oldman]  Christopher Nolan
# 4    [Taylor Kitsch, Lynn Collins, Samantha Morton]     Andrew Stanton

# %%
movies['overview'] = movies['overview'].apply(lambda x: x.split())
# Out:
# <ipython-input-47-3cac330698a6>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movies['overview'] = movies['overview'].apply(lambda x: x.split())

# %%
movies['genres'] = movies['genres'].apply(lambda x: [i.replace(" ", "") for i in x])
# Out:
# <ipython-input-48-ba8e48a7474e>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movies['genres'] = movies['genres'].apply(lambda x: [i.replace(" ", "") for i in x])

# %%
movies.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                             overview  \
# 0  [In, the, 22nd, century,, a, paraplegic, Marin...
# 1  [Captain, Barbossa,, long, believed, to, be, d...
# 2  [A, cryptic, message, from, Bond’s, past, send...
# 3  [Following, the, death, of, District, Attorney...
# 4  [John, Carter, is, a, war-weary,, former, mili...
#
#                                          genres  \
# 0  [Action, Adventure, Fantasy, ScienceFiction]
# 1                  [Adventure, Fantasy, Action]
# 2                    [Action, Adventure, Crime]
# 3              [Action, Crime, Drama, Thriller]
# 4           [Action, Adventure, ScienceFiction]
#
#                                             keywords  \
# 0  [culture clash, future, space war, space colon...
# 1  [ocean, drug abuse, exotic island, east india ...
# 2  [spy, based on novel, secret agent, sequel, mi...
# 3  [dc comics, crime fighter, terrorist, secret i...
# 4  [based on novel, mars, medallion, space travel...
#
#                                                cast           director
# 0  [Sam Worthington, Zoe Saldana, Sigourney Weaver]      James Cameron
# 1     [Johnny Depp, Orlando Bloom, Keira Knightley]     Gore Verbinski
# 2      [Daniel Craig, Christoph Waltz, Léa Seydoux]         Sam Mendes
# 3      [Christian Bale, Michael Caine, Gary Oldman]  Christopher Nolan
# 4    [Taylor Kitsch, Lynn Collins, Samantha Morton]     Andrew Stanton

# %%
movies['cast'] = movies['cast'].apply(lambda x: [i.replace(" ", "") for i in x])
movies['keywords'] = movies['keywords'].apply(lambda x: [i.replace(" ", "") for i in x])
# Out:
# <ipython-input-57-fcf1b4e1e269>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movies['cast'] = movies['cast'].apply(lambda x: [i.replace(" ", "") for i in x])
# <ipython-input-57-fcf1b4e1e269>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movies['keywords'] = movies['keywords'].apply(lambda x: [i.replace(" ", "") for i in x])

# %%
movies['director'] = movies['director'].apply(lambda x: [x])
# Out:
# <ipython-input-58-8406838109d0>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movies['director'] = movies['director'].apply(lambda x: [x])

# %%
movies['director'] = movies['director'].apply(lambda x: [i.replace(" ", "") for i in x])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-60-6cdae90a5bce> in <module>
# ----> 1 movies['director'] = movies['director'].apply(lambda x: [i.replace(" ", "") for i in x])
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwds)
#    4136             else:
#    4137                 values = self.astype(object)._values
# -> 4138                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    4139
#    4140         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-60-6cdae90a5bce> in <lambda>(x)
# ----> 1 movies['director'] = movies['director'].apply(lambda x: [i.replace(" ", "") for i in x])
#
# <ipython-input-60-6cdae90a5bce> in <listcomp>(.0)
# ----> 1 movies['director'] = movies['director'].apply(lambda x: [i.replace(" ", "") for i in x])
#
# AttributeError: 'NoneType' object has no attribute 'replace'

# %%
def replace(obj):
    for i in obj:
        if i:
            return [i.replace(" ", "")]

# %%
replace(movies.iloc[0]['director'])
# Out:
# ['JamesCameron']

# %%
movies['director'] = movies['director'].apply(replace)
# Out:
# <ipython-input-71-fc575e8401c0>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movies['director'] = movies['director'].apply(replace)

# %%
movies.isnull().sum()
# Out:
# movie_id     0
# title        0
# overview     0
# genres       0
# keywords     0
# cast         0
# director    30
# dtype: int64

# %%
movies[movies['director'].isnull()]
# Out:
#       movie_id                                              title  \
# 3669     19615                                          Flying By
# 3678    447027                                    Running Forever
# 3736     26379                                                Paa
# 3984     55831                                 Boynton Beach Club
# 4075    371085                                          Sharkskin
# 4112     48382    The Book of Mormon Movie, Volume 1: The Journey
# 4125    325140                             Hum To Mohabbat Karega
# 4130     20653                                     Roadside Romeo
# 4254    361505                              Me You and Five Bucks
# 4311    114065                          Down & Out With The Dolls
# 4320    137955                                          Crowsnest
# 4328    102840                                 Sex With Strangers
# 4380     47686                              Dream with the Fishes
# 4407     43630                                The Helix... Loaded
# 4411    357441                                  Karachi se Lahore
# 4464    279759                                Harrison Montgomery
# 4510    331493                            Light from the Darkroom
# 4559    380097                         America Is Still the Place
# 4568    297100                           The Little Ponderosa Zoo
# 4572    325579                                       Diamond Ruff
# 4577    328307  Rise of the Entrepreneur: The Search for a Bet...
# 4589     47546                                  I Want Your Money
# 4595     43743                                             Fabled
# 4639    300327                                        Death Calls
# 4644    378237                           Amidst the Devil's Wings
# 4650    325123                                    Teeth and Blood
# 4663    320435                                          UnDivided
# 4668     40963                                     Little Big Top
# 4680    194588                   Short Cut to Nirvana: Kumbh Mela
# 4722     38786  The Blood of My Brother: A Story of Death in Iraq
#
#                                                overview  \
# 3669  [A, real, estate, developer, goes, to, his, 25...
# 3678  [After, being, estranged, since, her, mother's...
# 3736  [He, suffers, from, a, progeria, like, syndrom...
# 3984  [A, handful, of, men, and, women, of, a, certa...
# 4075  [The, Post, War, II, story, of, Manhattan, bor...
# 4112  [The, story, of, Lehi, and, his, wife, Sariah,...
# 4125  [Raju,, a, waiter,, is, in, love, with, the, f...
# 4130  [This, is, the, story, of, Romeo., A, dude, wh...
# 4254  [A, womanizing, yet, lovable, loser,, Charlie,...
# 4311  [The, raunchy,, spunky, tale, of, the, rise, a...
# 4320  [In, late, summer, of, 2011,, five, young, fri...
# 4328  [For, some, married, couples,, sex, is, an, ob...
# 4380  [Terry, is, a, suicidal, voyeur, who, treats, ...
# 4407                                                 []
# 4411  [A, road, trip, from, Karachi, to, Lahore, whe...
# 4464                       [Film, from, Daniel, Davila]
# 4510  [Light, in, the, Darkroom, is, the, story, of,...
# 4559  [1971, post, civil, rights, San, Francisco, se...
# 4568  [The, Little, Ponderosa, Zoo, is, preparing, f...
# 4572  [Action, -, Orphan,, con, artist,, crime, boss...
# 4577  [The, world, is, changing, faster, than, ever....
# 4589  [Two, versions, of, the, American, dream, now,...
# 4595  [Joseph, just, broke, up, with, his, girlfrien...
# 4639  [An, action-packed, love, story, on, the, Mexi...
# 4644               [Prequel, to, "5th, of, a, Degree."]
# 4650  [A, beautiful, diva, is, murdered, on, the, se...
# 4663  [UnDivided, documents, the, true, story, of, h...
# 4668  [An, aging, out, of, work, clown, returns, to,...
# 4680  [Every, 12, years, over, 70, million, pilgrims...
# 4722  [THE, BLOOD, OF, MY, BROTHER, goes, behind, th...
#
#                                 genres           keywords  \
# 3669                           [Drama]                 []
# 3678                          [Family]                 []
# 3736          [Drama, Family, Foreign]                 []
# 3984          [Comedy, Drama, Romance]  [independentfilm]
# 4075                                []                 []
# 4112                                []                 []
# 4125                                []                 []
# 4130      [Animation, Family, Foreign]                 []
# 4254          [Romance, Comedy, Drama]                 []
# 4311                   [Comedy, Music]                 []
# 4320                                []                 []
# 4328                     [Documentary]                 []
# 4380                          [Comedy]  [independentfilm]
# 4407  [Action, Comedy, ScienceFiction]                 []
# 4411                  [Family, Comedy]                 []
# 4464                                []                 []
# 4510                                []                 []
# 4559                                []                 []
# 4568                                []                 []
# 4572                                []                 []
# 4577                                []                 []
# 4589                     [Documentary]                 []
# 4595        [Drama, Mystery, Thriller]  [independentfilm]
# 4639                                []                 []
# 4644            [Drama, Action, Crime]                 []
# 4650                          [Horror]                 []
# 4663                                []                 []
# 4668                          [Comedy]  [independentfilm]
# 4680                                []                 []
# 4722                                []                 []
#
#                                                    cast director
# 3669  [BillyRayCyrus, HeatherLocklear, AhnaiseChrist...     None
# 3678                                                 []     None
# 3736    [AmitabhBachchan, AbhishekBachchan, VidyaBalan]     None
# 3984         [BrendaVaccaro, DyanCannon, JosephBologna]     None
# 4075                                                 []     None
# 4112                      [KirbyHeyborne, MichaelFlynn]     None
# 4125                                                 []     None
# 4130         [SaifAliKhan, KareenaKapoor, JavedJaffrey]     None
# 4254                                                 []     None
# 4311                                                 []     None
# 4320                                                 []     None
# 4328                                                 []     None
# 4380             [DavidArquette, BradHunt, KathrynErbe]     None
# 4407                                                 []     None
# 4411          [ShehzadSheikh, AyeshaOmar, YasirHussain]     None
# 4464                                                 []     None
# 4510                                                 []     None
# 4559                                                 []     None
# 4568                                                 []     None
# 4572                                                 []     None
# 4577                                                 []     None
# 4589                                                 []     None
# 4595                                                 []     None
# 4639                                                 []     None
# 4644                                                 []     None
# 4650  [GlennPlummer, MichelleVanDerWater, DanielleVega]     None
# 4663                                                 []     None
# 4668               [SidHaig, RichardRiehle, MelEngland]     None
# 4680                                                 []     None
# 4722                                                 []     None

# %%
dataset[dataset['movie_id'] == 19615]
# Out:
#       budget                         genres homepage     id keywords  \
# 3669       0  [{"id": 18, "name": "Drama"}]      NaN  19615       []
#
#      original_language original_title  \
# 3669                en      Flying By
#
#                                                overview  popularity  \
# 3669  A real estate developer goes to his 25th high ...    1.546169
#
#      production_companies  ... runtime  \
# 3669                   []  ...    95.0
#
#                               spoken_languages    status  \
# 3669  [{"iso_639_1": "en", "name": "English"}]  Released
#
#                    tagline      title vote_average vote_count movie_id  \
# 3669  It's about the music  Flying By          7.0          2    19615
#
#                                                    cast  crew
# 3669  [{"cast_id": 1, "character": "George", "credit...    []
#
# [1 rows x 23 columns]
